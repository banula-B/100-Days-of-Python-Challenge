# %%
import json

# %% [markdown]
# # Exercise No: 01

# %%
book = {
    "title": "The Hobbit",
    "author": "J.R.R. Tolkien",
    "genres": ["Fantasy", "Adventure"],
    "available": True
}

json_string = json.dumps(book, indent = 2)

print(json_string)
# Out:
# {
#   "title": "The Hobbit",
#   "author": "J.R.R. Tolkien",
#   "genres": [
#     "Fantasy",
#     "Adventure"
#   ],
#   "available": true
# }

# %% [markdown]
# # Exercise No: 02

# %% [markdown]
# # Exercise No: 03
