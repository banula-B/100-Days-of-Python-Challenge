# %% [markdown]
# # Exercise No: 01

# %%
# List with favourite movies

fav_movies = ["The Odyssey",
    "Toy Story 5",
    "Supergirl",
    "Evil Dead Burn",
    "Spider-Man: Brand New Day"
]

# Set the second item on the movie list as second favourite movie

second_fav_movie = fav_movies[1]

print("Your second favorite movie is:",second_fav_movie)

# %% [markdown]
# # Exercise No: 02

# %%
# Number list

numbers = [10, 20, 30, 40, 50]

# Change the value 30 to 35

numbers[2] = 35

print(numbers)

# %% [markdown]
# # Exercise No: 03

# %%
# Get 5 user inputs and store in a list

number_list=[]

number=1
sum = 0

while number<=5:
    user_number= int(input(f"Enter Number {number} :"))
    number_list.append(user_number)
    number+=1

total = sum(number_list)

print("sum:", total)

# %%
# Get 5 user inputs and store in a list

number_list = []

number = 1

while number <= 5:
    user_number = int(input(f"Enter Number {number}: "))
    number_list.append(user_number)
    number += 1

total = sum(number_list)

print("sum:", total)
