# %% [markdown]
# # Exercise No: 01

# %%
list(map(lambda name: name.strip().capitalize(), [" alice ", "bob ", " CHARLIE "]))
# Out:
# ['Alice', 'Bob', 'Charlie']

# %% [markdown]
# # Exercise No: 02

# %% [markdown]
# # Exercise No: 03
