# %% [markdown]
# # Exercise No: 01

# %%
str_list=["1", "2", "3"]

num_list=list(map(lambda x: int(x) , str_list))

print(num_list)

# Confirm the tpe of num_list elements
print(type(num_list[0]))
# Out:
# [1, 2, 3]
# <class 'int'>

# %% [markdown]
# # Exercise No: 02

# %%
names = ["alice", "bob", "charlie"]

cap_names = list(map(lambda x: x.capitalize(), names)) # you can use .title() also to make first letter capital

print(cap_names)
# Out:
# ['Alice', 'Bob', 'Charlie']

# %% [markdown]
# # Exercise No: 03

# %%
price_list=[1250, 1000, 999, 1100]

price_with_tax = list(map(lambda x: x* 1.10 , price_list)) 

print(price_with_tax)
# Out:
# [1375.0, 1100.0, 1098.9, 1210.0]
