# %% [markdown]
# # Exercise No: 01

# %%
multiply = lambda x : x * 10

print(multiply(3))
# Out:
# 30

# %% [markdown]
# # Exercise No: 02

# %%
power = lambda x, y: x**y

print(power(2,4))
# Out:
# 16

# %% [markdown]
# # Exercise No: 03

# %%
odd_or_even = lambda x : x % 2== 0

print(odd_or_even(4))
print(odd_or_even(3))
# Out:
# True
# False
