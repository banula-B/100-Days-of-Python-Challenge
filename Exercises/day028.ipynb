# %%
from functools import reduce

# %% [markdown]
# # Exercise No: 01

# %%
numbers = [10, 25, 7, 42, 18]

maximum = reduce(lambda x, y: x if x > y else y, numbers)

print(maximum)

# %% [markdown]
# # Exercise No: 02

# %% [markdown]
# # Exercise No: 03
