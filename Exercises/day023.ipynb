# %% [markdown]
# # Exercise No: 01

# %%
def square(number):
    return number**2

square = square(4)

print(square)
# Out:
# 16

# %% [markdown]
# # Exercise No: 02

# %%
def get_full_name(first, last):
    return first+" "+ last

full = get_full_name("banula","bimsara")
print(full.title())
# Out:
# Banula Bimsara

# %% [markdown]
# # Exercise No: 03

# %%
def min_max(numbers_list):
    return min(numbers_list), max(numbers_list)

result = min_max([2,4,7,5,8,1])
print(result)
# Out:
# (1, 8)
