# %% [markdown]
# # Exercise No: 01

# %%
import random as rand

# %%
print("Rolling the dice...")
a = rand.randint(1,6)

print(f"You rolled: {a}")
# Out:
# Rolling the dice...
# You rolled: 6

# %% [markdown]
# # Exercise No: 02

# %% [markdown]
# # Exercise No: 03
