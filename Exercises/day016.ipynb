# %% [markdown]
# # Exercise No:01

# %%
#List with 5 animals
animal=['cat', 'elephant', 'dog', 'rabbit', 'lion']

second=input("Enter animal name: ")

# Add user input to the second item of list
animal.insert(1,second)
# Remove last item of list
animal.pop()

print(animal)

# %% [markdown]
# # Exercise No:02

# %%
numbers = [10, 20, 20, 30, 20, 40]

twenty=numbers.count(20)
print(f"20 appears {twenty} times")
# Out:
# 20 appears 3 times

# %% [markdown]
# # Exercise No:03

# %%
names= ["Charlie", "Alice", "David", "Bob"]
names.sort()

print(names)
# Out:
# ['Alice', 'Bob', 'Charlie', 'David']
