# %% [markdown]
# # Exercise No: 01

# %%
names = ["Alice", "Bob", "Anna", "Dave"]

name_list = list(filter(lambda name: name[0]=="A" , names))

print(name_list)
# Out:
# ['Alice', 'Anna']

# %% [markdown]
# # Exercise No: 02

# %% [markdown]
# # Exercise No: 03
