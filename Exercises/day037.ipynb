# %%
import csv

# %% [markdown]
# # Exercise No: 01

# %%
grocery = ["Hammer", 2, 12.50]

with open(r"../Resources\csv files\inventory.csv", "a", newline="") as file:
    writer = csv.writer(file)

    
    writer.writerow(grocery)

# %% [markdown]
# # Exercise No: 02

# %% [markdown]
# # Exercise No: 03
