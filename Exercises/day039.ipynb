# %%
import random

# %% [markdown]
# # Exercise No: 01

# %%
# You can choose any method

values = ["Head","Tail"]

choice = random.choice(values)

print(choice)

# choice = random.randint(0,1)

# if choice == 0:
#     print("Head")
# else:
#     print("Tail")
# Out:
# Head

# %% [markdown]
# # Exercise No: 02

# %%
student_list = ["virat","kumar","shakib","joe","kane","david","ricky","shoib"]

student_of_day = random.choice(student_list)
presenting_team = random.sample(student_list,3) 

print(f"Student of the day is {student_of_day}")
print(f"Presenting group members are - {presenting_team}")
# Out:
# Student of the day is david
# Presenting group members are - ['kumar', 'shoib', 'kane']

# %% [markdown]
# # Exercise No: 03
