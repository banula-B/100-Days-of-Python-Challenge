# %%
import random

# %% [markdown]
# # Exercise No: 01

# %%
# You can choose any method

values = ["Head","Tail"]

choice = random.choice(values)

print(choice)

# choice = random.randint(0,1)

# if choice == 0:
#     print("Head")
# else:
#     print("Tail")
# Out:
# Head

# %% [markdown]
# # Exercise No: 02

# %% [markdown]
# # Exercise No: 03
