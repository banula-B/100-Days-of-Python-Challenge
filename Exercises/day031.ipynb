# %% [markdown]
# # Exercise No:01

# %%
with open(r"..\Resources\text files\sample.txt","r") as file:
    content=file.read()
    print(content)
# Out:
# This is a sample text file
# It contains multiple lines of text
# We will use this for practicing file reading operations
#
# My note is here
#
# Note: Buy milk
# NOTE: Finish homework
# note: Call John
# Important Note: Read this
# My note is here

# %% [markdown]
# # Exercise No:02

# %%
with open (r"..\Resources\text files\sample.txt", "r") as file:
    content = file.read()

    #Total characters
    total_characters = len(content)
    print(f"Total Characters = {total_characters}")

    total_words = len(content.split())
    print(f"Total Words = {total_words}")
# Out:
# Total Characters = 230
# Total Words = 42

# %% [markdown]
# # Exercise No:03

# %%
with open(r"..\Resources\text files\sample.txt","r") as file:
    for line in file:
        if line.strip().lower().startswith("note"):
            print(line)
# Out:
# Note: Buy milk
#
# NOTE: Finish homework
#
# note: Call John
