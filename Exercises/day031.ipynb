# %% [markdown]
# # Exercise No:01

# %%
with open(r"..\Resources\sample.txt","r") as file:
    content=file.read()
    print(content)
# Out:
# This is a sample text file.
# It contains multiple lines of text.
# We will use this for practicing file reading operations.

# %% [markdown]
# # Exercise No:02

# %%
with open(r"..\Resources\sample.txt","r") as file:
    content = file.read()

# Total number of character with spaces
characters = len(content)
print(characters)
# Total number of words
words = len(content.split())
print(words)
# Out:
# 117
# 21

# %% [markdown]
# # Exercise No:03
