# %% [markdown]
# # Exercise No: 01

# %%
list1 = [2,5,7,12,19]
sum = 0

for num in list1:
    sum += num
    
print(f"Sum of list: {sum}")
print(f"Average of list: {(sum)/len(list1)}")
# Out:
# Sum of list: 45
# Average of list: 9.0
