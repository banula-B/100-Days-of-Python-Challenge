# %%
#This is a simple exercise to check if a number is positive or negative

n= int(input("Enter any Number: "))

if n > 0:
    print("Positive!")
else:
    print("Negative!")
# Out:
# Positive!

# %%
#This is a simple exercise to check if a password is correct or not

password = input("Enter your password: ")

if password == "python123":
    print("Access Granted")
    
else:
    print("Access Denied")
# Out:
# Access Denied

# %%
#This is a simple exercise to check if you are the Admin or not

name = input("Enter your name: ")

if name == "Admin123":
    print("Welcome, System Administrator.")
else:
    print("Access Denied")
# Out:
# Access Denied
