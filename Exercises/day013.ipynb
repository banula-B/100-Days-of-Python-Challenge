# %% [markdown]
# # Exercise No: 01
#
# This is for print 5*5 grid using nested loop

# %%
# Print a 5 × 5 grid of hash symbols

for row in range(5):
    for col in range(5):
        print("#", end="")
    print()
# Out:
# #####
# #####
# #####
# #####
# #####
