# %% [markdown]
# # Exercise No: 01

# %%
from datetime import datetime

current_time = datetime.now().strftime("%H:%M:%S")
print(current_time)
# Out:
# 10:51:57

# %% [markdown]
# # Exercise No: 02

# %%
from datetime import datetime

birthday = input("Enter your birthday (DD/MM/YYYY): ")

date = datetime.strptime(birthday, "%d/%m/%Y")

print("You were born on:", date.strftime("%A"))
# Out:
# You were born on: Saturday

# %% [markdown]
# # Exercise No: 03

# %%
from datetime import datetime, timedelta

current_time = datetime.now()
future_time = current_time + timedelta(minutes=10000)

print("10,000 minutes from now:", future_time)
# Out:
# 10,000 minutes from now: 2026-09-06 09:34:11.773939
