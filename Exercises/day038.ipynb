# %% [markdown]
# # Exercise No: 01

# %%
from datetime import datetime

current_time = datetime.now().strftime("%H:%M:%S")
print(current_time)
# Out:
# 10:51:57

# %% [markdown]
# # Exercise No: 02

# %% [markdown]
# # Exercise No: 03
