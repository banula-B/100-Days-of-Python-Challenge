# %% [markdown]
# # Exercise No: 01

# %%
# This is a dictionary includes a car details

car = {
    "brand": "Toyota", 
    "model": "Prius",
    "year": "2013"
}

print(f"Model: {car["model"]}")
# Out:
# Model: Prius

# %% [markdown]
# # Exercise No: 02

# %%
# Change the year of car
car["year"]= 2024

#Add a color value to the car

car["color"] = "silver"

print(car)
# Out:
# {'brand': 'Toyota', 'model': 'Prius', 'year': 2024, 'color': 'silver'}

# %% [markdown]
# # Exercise No: 03

# %%
# Loop through car dictionary

car.items()

for key,value in car.items():
    print(f"{key}: {value}")
# Out:
# brand : Toyota
# model : Prius
# year : 2024
# color : silver
