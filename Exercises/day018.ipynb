# %% [markdown]
# # Exercise No: 01

# %%
# This is a dictionary includes a car details

car = {
    "brand": "Toyota", 
    "model": "Prius",
    "year": "2013"
}

print(f"Model: {car["model"]}")
# Out:
# Model: Prius

# %% [markdown]
# # Exercise No: 02

# %% [markdown]
# # Exercise No: 03
