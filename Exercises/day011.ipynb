# %% [markdown]
# # Exercise No: 01
#
# This exercise print all letters your input name

# %%
# Take user input

name = input("Enter Your Name")

# for loop

for char in name:
    print(char)
# Out:
# B
# a
# n
# u
# l
# a
