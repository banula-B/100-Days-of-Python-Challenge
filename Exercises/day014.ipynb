# %% [markdown]
# # Exercise No: 01

# %%
for i in range(1, 11):
    if i == 7:
        break
    print(i)

# %% [markdown]
# # Exercise No: 02

# %%
total = 0

while True:
    number = int(input("Enter a number: "))

    if number == 0:
        break

    if number < 0:
        continue

    total += number

print("Total:", total)

# %% [markdown]
# # Exercise No: 03

# %%
languages = ["Java", "C++", "Python", "JavaScript"]

for language in languages:
    if language == "Python":
        print("Found it!")
        break
