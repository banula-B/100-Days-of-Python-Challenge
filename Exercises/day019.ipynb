# %% [markdown]
# # Exercise No: 01

# %%
my_hobbies={"Reading", "Hiking", "Painting"}

my_hobbies.add("Cooking")

# %% [markdown]
# # Exercise No: 02

# %%
set1 = {10, 20, 30}
set2 = {30, 40, 50}

print(set1 & set2)
# Out:
# {30}

# %% [markdown]
# # Exercise No: 03

# %%
my_set = {[1, 2, 3]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 my_set = {[1, 2, 3]}
#
# TypeError: cannot use 'list' as a set element (unhashable type: 'list')

# %% [markdown]
# A set can only contain hashable objects. Python uses an object's hash value to efficiently store and look up set elements
