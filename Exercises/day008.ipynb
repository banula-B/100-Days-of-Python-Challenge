# %%
# This is for check user input first number is high or low than second number

num1=int(input("Enter your number 1: "))
num2=int(input("Enter your number 2: "))


if num1>num2:
    print("True")
else:
    print("False")
# Out:
# False

# %%
# check if a user age is 21 or not

age= int(input("Enter Your Age: "))

if age==21:
    print("You're 21 Years old")
else:
    print("You are not exactly 21 years old.")
# Out:
# You are not exactly 21 years old.

# %%
# check the tempurature is freezing or not

temp = int(input("Enter tempurature: "))

if temp<=0:
    print("It is freezing!")
else:
    print("It is not freezing")
# Out:
# It is not freezing
