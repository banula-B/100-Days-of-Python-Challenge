# %% [markdown]
# # Exercise No: 01

# %%
with open(r"..\Resources\text files\about_me.txt","w") as file:
    file.write("My name is Banula\n")
    file.write("I'm from Sri Lanka\n")
    file.write("I want to be a python developer\n")

# %% [markdown]
# # Exercise No: 02

# %%
numbers = [10, 20, 30, 40, 50]

with open(r"..\Resources\text files\number.txt", "w") as file:
    for number in numbers:
        file.write(f"{number}\n")

# %% [markdown]
# # Exercise No: 03

# %%
sentence=input("Enter Your Sentence")

if sentence.strip()=="":
    print("Input can't be empty")
else:
    with open(r"..\Resources\text files\user_input.txt","w") as file:
        file.write(sentence)
