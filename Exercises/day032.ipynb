# %% [markdown]
# # Exercise No: 01

# %%
with open(r"..\Resources\about_me.txt","w") as file:
    file.write("My name is Banula\n")
    file.write("I'm from Sri Lanka\n")
    file.write("I want to be a python developer\n")

# %% [markdown]
# # Exercise No: 02

# %% [markdown]
# # Exercise No: 03
