# %% [markdown]
# # Exercise No: 01

# %%
with open (r"../Resources/text files/about_me.txt", "w") as file:
    name = file.write(f"Hi. I'm Banula Bimsara\n")
    counrty = file.write(f"I'm From Sri Lanka\n")
    learning_goal = file.write(f"My Learning Goal is to Master Python Language")

# %% [markdown]
# # Exercise No: 02

# %%
numbers = [1,3,5,6,4,8,12,15,21]

with open(r"../Resources/text files/number.txt", "w") as file:
    for number in numbers:
        line = str(number) + "\n"
        file.write(line)

        # To check the numbers write into number.txt uncomment below line
        # print(line)

# %% [markdown]
# # Exercise No: 03

# %%
user_input = input("Enter Your Wish!")

if not user_input:
    print("You entered nothing!. please enter something!.")

else:
    with open (r"../Resources/text files/user_input.txt", "w") as file:
        file.write(user_input)

        print(f"Successfully entered > {user_input}")
# Out:
# Successfully entered > I love learning python
