# %% [markdown]
# # Exercise No: 01

# %%
# Create a function

def greet_user():
    print("Welcome to Phase 2: Functions!")

greet_user()
# Out:
# Welcome to Phase 2: Functions!

# %% [markdown]
# # Exercise No: 02

# %%
def show_date():
    print("13/08/2026")

show_date()
# Out:
# 13/08/2026

# %% [markdown]
# # Exercise No: 03

# %%
def start_program():
    print("You have started the program")

def end_program():
    print("You have end the program")

start_program()
end_program()
# Out:
# You have started the program
# You have end the program
