# %% [markdown]
# # Exercise No: 01

# %%
# This tuple store my data

personal_data="Banula Bimsara",23,"Red"

print(personal_data)
# Out:
# ('Banula Bimsara', 23, 'Red')

# %% [markdown]
# # Exercise No: 02

# %%
# This is to show error in tuple editing

lis=(2,3,5,6)

lis[2]=0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 # This is to show error in tuple editing
#       2
#       3 lis=(2,3,5,6)
#       4
# ----> 5 lis[2]=0
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Exercise No: 03

# %%
# Unpack tuple

color = (225, 0, 0)

red,green,blue = color

print(red)
print(green)
print(blue)
# Out:
# 225
# 0
# 0
