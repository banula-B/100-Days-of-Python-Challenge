# %% [markdown]
# # Exercise No: 01

# %%
try:
    age = int(input("Enter Your Age: "))
except ValueError:
    print("Please enter a numerical value.")

finally:
    print(f"Your age: {age}")
# Out:
# Your age: 12

# %% [markdown]
# # Exercise No: 02

# %% [markdown]
# # Exercise No: 03
