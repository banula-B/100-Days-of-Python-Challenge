# %% [markdown]
# # Exercise No: 01

# %%
try:
    age = int(input("Enter Your Age: "))
except ValueError:
    print("Please enter a numerical value.")

# %% [markdown]
# # Exercise No: 02

# %% [markdown]
# # Exercise No: 03
