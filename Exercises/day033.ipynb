# %% [markdown]
# # Exercise No: 01

# %%
with open(r"..\Resources\text files\about_me.txt","a") as file:
    file.write("\nPS: I am currently learning about file appending!")

# %% [markdown]
# # Exercise No: 02

# %%
for i in range(3):
    item = input("Enter Item: ")

    with open(r"..\Resources\text files\wishlist.txt","a") as file:
        file.write(f"{item}\n")

# %% [markdown]
# # Exercise No: 03

# %%
with open(r"..\Resources\text files\counter.txt", "a+") as file:
    file.seek(0)
    number = file.read().splitlines()

    new_number= 1 if not number else int(number[-1]) + 1

    file.write(f"{new_number}\n")
