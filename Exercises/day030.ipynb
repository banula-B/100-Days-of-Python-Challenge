# %% [markdown]
# # Exercise No: 01

# %% [markdown]
# For the game package with two modules, there should be a __ init __ file
#
# games/
# │
# ├── __ init __.py
# ├── chess.py
# └── tic_tac_toe.py

# %% [markdown]
# # Exercise No: 02

# %% [markdown]
# # Exercise No: 03
